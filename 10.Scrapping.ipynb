# %% [markdown]
# # Работа с xml и html
#
# Будем использовать пакет lxml (http://lxml.de/)

# %%
import lxml.html
import lxml.etree
import requests

# %% [markdown]
# Пусть есть некоторый xml.

# %%
our_xml = """
                <root>
                    <a>
                        text1
                        <d q='d1'>
                          text d1
                        </d>
                        <d q='d2'>
                          text d2
                        </d>
                    </a>
                    
                    <b q='7'>                    
                        text b
                    </b>
                    
                    <b q='5'>
                        text 3
                        <d q='d3'>
                           text d3
                        </d>
                    </b>
                    
                </root>
            """

# %%
tree = lxml.etree.fromstring(our_xml)

# %% [markdown]
# Получаем дерево

# %%
for child in tree.getchildren():
    print(child.tag, child.attrib)
# Out:
# a {}
# b {'q': '7'}
# b {'q': '5'}

# %% [markdown]
# Удобные методы для XPath запросов:

# %% [markdown]
# Все узлы с именем `<d>`

# %%
tree.xpath('//d')
# Out:
# [<Element d at 0x7f0751613a48>,
#  <Element d at 0x7f075162b648>,
#  <Element d at 0x7f075162bb08>]

# %% [markdown]
# Узел `<b>`, который является потомком узкла `<root>` и имеет аттрибут `q` равный 7

# %%
tree.xpath('/root/b[@q="7"]')
# Out:
# [<Element b at 0x7f075162be08>]

# %% [markdown]
# Значения атрибута `q` у всех узлов `<d>` которые являются потомками всех узлов `<a>`

# %%
tree.xpath('//a//d/@q')
# Out:
# ['d1', 'd2']

# %% [markdown]
# Взять текстовый контент узла `<d>` с атрибутом `q` равным `d1`, который является прямым потомком узла `<a>`, который является прямым потомком корневого элемента.

# %%
tree.xpath('/root/a/d[@q="d1"]/text()')
# Out:
# ['\n                          text d1\n                        ']

# %% [markdown]
# Когда xml большой (дамп Википедии), на помощь приходит SAX-like парсеры

# %%
import xml.sax
import io

class MyContentHandler(xml.sax.ContentHandler):
    def __init__(self):
        self.level = 0
    
    def startElement(self, name, attributes):
        self.level += 1
        print('  ' * self.level, 'Start <%s>' % name, 'attr:', attributes.items())        
        
    def endElement(self, name):
        print('  ' * self.level, 'End </%s>' % name)
        self.level -= 1

    def characters(self, data):
        text = data.strip()
        if len(text) > 0:
            print('  ' * self.level, ' Text:', text)
        
handler = MyContentHandler()
parser = xml.sax.make_parser()
parser.setContentHandler(handler)
parser.parse(io.StringIO(our_xml))
#parser.parse(open('data/wiki.xml'))
# Out:
#    Start <root> attr: []
#      Start <a> attr: []
#       Text: text1
#        Start <d> attr: [('q', 'd1')]
#         Text: text d1
#        End </d>
#        Start <d> attr: [('q', 'd2')]
#         Text: text d2
#        End </d>
#      End </a>
#      Start <b> attr: [('q', '7')]
#       Text: text b
#      End </b>
#      Start <b> attr: [('q', '5')]
#       Text: text 3
#        Start <d> attr: [('q', 'd3')]
#         Text: text d3
#        End </d>
#      End </b>
#    End </root>

# %% [markdown]
# C HTML можно работать аналогичным образом, lxml пытается привести его к нормальному виду (добавить необходимые по спецификации теги, исправить ошибки и пр.)

# %%
response = requests.get('http://fontanka.ru')
response.status_code
# Out:
# 200

# %%
print(response.text.strip()[:120])
# Out:
# <!DOCTYPE html><html lang="ru"><head><meta charset="utf-8"><meta name="mobile-web-app-capable" content="yes"><meta name=

# %%
tree = lxml.html.fromstring(response.text)

# %%
tree.xpath('//title/text()')
# Out:
# ['Новости Санкт-Петербурга - главные новости сегодня | fontanka.ru - новости Санкт-Петербурга']

# %%
tree.xpath('//a[@class="FVd5"]/text()')
# Out:
# ['Как сделать прививку от ковида экспериментальной вакциной и сколько можно на этом заработать.',
#  'Трусы на голове и компьютерный коронавирус. На фоне пандемии COVID-19 врачи заговорили о психической эпидемии',
#  'Умерла мать Федора Бондарчука актриса Ирина Скобцева',
#  'Гаишники в Зеленогорске нашли одинокий X-Trail в кювете. А потом — угонщика, знакомого с хозяйкой',
#  'Наш проект: 200 новых сотрудников. Кого ждут на «Ижорских заводах»?',
#  'РПЛ выступила с заявлением о ситуации в «Краснодаре». Матч Лиги чемпионов проведут',
#  'Обезглавленного во Франции учителя наградят орденом Почетного легиона',
#  'Вакцинация россиян «Спутником V» начнется уже в конце ноября',
#  '«Гольф» полыхал посреди ночи на Варфоломеевской. Пострадавшего госпитализировали с ожогами ягодиц',
#  'Горожан в Москве хотят отслеживать через смартфоны',
#  'На соцдоплаты неработающим пенсионерам 12 регионов выделят более 903 млн рублей. В том числе Петербургу',
#  'Жена Ефремова перед апелляцией прервала переговоры с потерпевшими, заподозрив адвокатов в сговоре',
#  'Шарапова купила ранчо в Калифорнии за 8,6 млн долларов',
#  'Мошенники нашли петербургского пенсионера через рекламу на патриотическом радио. Прикрывались звёздами на погонах, разыграли спектакль',
#  'Мурманское МЧС показывает, как при волнах 2,5 метра ищут рыбаков затонувшего судна',
#  'Рубинштейна будет пешеходной только по ночам в выходные. Начнут уже на этой неделе',
#  'Как выбрать место для магазина в Интернете? «Фонтанка» приглашает петербургских предпринимателей на бесплатную онлайн-конференцию',
#  'ДТП на Стачек попало на видео: нарушитель отправился на газон, высекая искры',
#  'Петербуржцы пожаловались на педофилов в двух районах Петербурга. Пострадали дети 7 и 12 лет',
#  'Автомобилисты досыпают в пробке на проспекте Луначарского. Дорогу залило из дефектной трубы',
#  'Во всей Туве пропало электричество из-за аварийного отключения',
#  'СПЧ вынес отрицательное заключение на законопроект об изъятии детей из семьи только по решению суда',
#  'Петербуржец позволил себе лишнего в телефонном разговоре с сотрудником банка. Полиция приехала к нему домой через полчаса',
#  'Начинается «охота на ведьм»: посольство России в США высказалось по поводу обвинений россиян в кибератаках',
#  'Упавшую с моста в Фонтанку девушку спасали очевидцы',
#  'Следователь рассчитывала на 10 миллионов. ФСБ Петербурга задержала ее с дисконтом',
#  '«Фонтанка» приглашает на круглый стол «Инвестиционный климат: переменная облачность, перспективы потепления»',
#  'Петербуржец получил пулю в ресторане грузинской кухни на Варшавской',
#  'РБК: Власти исключают повторное введение режима нерабочих недель',
#  'Студенты из Китая продемонстрировали в кафе на Васильевском острове «стиль пьяного мастера». Троих увезли в больницу',
#  'Роспотребнадзор предупредил об опасности самостоятельного приема антибиотиков при гриппе',
#  'Один белый, другой серый — два «Фольксвагена» разбились на Стачек',
#  'В Крыму могут построить опреснительные установки за 8 млрд рублей',
#  'Женщина получила тяжёлые травмы на КАД: врезалась в стоящий грузовик',
#  'Эксперты рассчитали, когда Россия пройдет пик заражения коронавирусом',
#  'В Госдуму внесли законопроект, разрешающий приходить на митинги в масках',
#  'И снег, и солнце обещают синоптики Петербургу. По ночам подмораживает',
#  'Минфин предложил сократить сто тысяч должностей в армии и увеличить срок выслуги для военной пенсии',
#  'Музыка барокко и костюмы Chanel: фестиваль «Дягилев. P.S.» возвращается в Петербург',
#  'Ученые «разберут на атомы» дешевую энергию, генную терапию и влияние соцсетей на реальные отношения',
#  'Полдела сделано. На МКС починили туалет, с системой получения кислорода сложней — в ней закончилась вода',
#  'Армения заявила, что в Карабахе сбиты пять азербайджанских беспилотников',
#  'Своя машина — хорошо, но на метро лучше. Каждый второй петербуржец ездит на работу на общественном транспорте',
#  'Россия поставила Китаю сверхплановый газ',
#  'Статистика суточной смертности от COVID-19 в Москве падает',
#  'Ирландия вернула наивысший уровень ограничений из-за COVID-19. Закроют всё, кроме школ, детсадов и строек',
#  'На МКС задымился пылесос, пузырь в туалете и снова проблемы с кислородом',
#  'Продажи жилья бизнес-класса в Москве установили новый рекорд',
#  'Гран-при Франции по фигурному катанию отменили из-за COVID-19',
#  'Еще двоих белорусских журналистов арестовали на 15 суток после акций протеста в Минске',
#  '«Мы развязываем руки нашим парням без правил». Историк Соколов подал заявление об угрозах убийством в свой адрес',
#  'Тиньков рассказал, почему сорвалась сделка с «Яндексом» и извинился за оскорбительные слова в адрес компании',
#  'Вылечившийся Брагин привел СКА к победе над «Витязем»',
#  'Главный тренер «Брюгге» заявил, что у прилетевших в Петербург симптомов COVID-19 нет',
#  'Британские власти заявили, что хакеры из российской военной разведки пытались сорвать Олимпийские игры в Токио',
#  'РЖД добавит «Ласточек» из Петербурга в Рускеалу на новогодних каникулах',
#  'Минюст США предъявил обвинения в атаке на Олимпиаду 2018 и выборы во Франции шести российским хакерам',
#  'На ЗСД фура уходила от столкновения и врезалась в отбойник. Виновник предпочел не останавливаться',
#  '«Коммерсантъ»: Госдума отложила законопроект о защите граждан от хамства чиновников',
#  '«После 23:00 есть вредно». Смольный объяснил причины ограничения времени работы ресторанов',
#  '«Придется смириться». Вице-губернатор Елин — о «комендантском часе» для общепита Петербурга и новых ограничениях',
#  'Один из пострадавших после ДТП в Купчино воспитанников социального центра остается в больнице',
#  'Россиянам предложат вернуть налоги за занятие спортом и фитнесом',
#  'Европа покраснела от ковида. ЕК создала карту распространения вируса',
#  'Наш проект: Как стать госслужащим нового типа?',
#  'Четырех школьников задержали после казни учителя в Париже',
#  'Спасалась от изнасилования, расчленила от страха тюрьмы. Что известно об оправдании петербурженки в убийстве',
#  'Пострадавших в Купчино детей обследуют в больнице. Самый младший — второклассник',
#  'За пробежку по полицейской машине на площади Восстания хулигана изолировали на пять суток',
#  'Петербургский лор-врач: После COVID-19 обоняние возвращается, а после гриппа мы рискуем потерять его навсегда',
#  'Как сделать прививку от ковида экспериментальной вакциной и сколько можно на этом заработать.',
#  'Трусы на голове и компьютерный коронавирус. На фоне пандемии COVID-19 врачи заговорили о психической эпидемии',
#  'Умерла мать Федора Бондарчука актриса Ирина Скобцева',
#  'Гаишники в Зеленогорске нашли одинокий X-Trail в кювете. А потом — угонщика, знакомого с хозяйкой',
#  'Наш проект: 200 новых сотрудников. Кого ждут на «Ижорских заводах»?',
#  'РПЛ выступила с заявлением о ситуации в «Краснодаре». Матч Лиги чемпионов проведут',
#  'Обезглавленного во Франции учителя наградят орденом Почетного легиона',
#  'Вакцинация россиян «Спутником V» начнется уже в конце ноября',
#  '«Гольф» полыхал посреди ночи на Варфоломеевской. Пострадавшего госпитализировали с ожогами ягодиц',
#  'Горожан в Москве хотят отслеживать через смартфоны']
